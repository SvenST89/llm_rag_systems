# %%
import sys
sys.path.append("/workspaces/20241123_RAG_System/src")
from src.kgbackend.graph_rag import GraphRAG
from langchain_community.document_loaders import UnstructuredPDFLoader, PyPDFLoader

# %%
path = "./src/data/20200414_IMF_Preliminary World Economic Outlook Report.pdf"
loader = PyPDFLoader(path)
docs = loader.load()

# %%
graph_rag = GraphRAG()

# %%
graph_rag.process_documents(docs)
# Out:
# Extracting concepts and entities: 100%|██████████| 171/171 [00:31<00:00,  5.37it/s]
# Adding edges: 100%|██████████| 171/171 [00:00<00:00, 1613.67it/s]

# %%
query="what was the economic outlook for Germany in 2020?"
response = graph_rag.query(query=query)
